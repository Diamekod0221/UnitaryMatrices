# %% [markdown]
# // Potestować większe generatory blokowe - większe R
# Opisać porównanie metod PCG, ginibre - jakość, czas, etc
# Porównać czas przy iteracji na tej samej dokładności (wyskalować ginibre i cmc tak, żeby wariancja była taka sama)
